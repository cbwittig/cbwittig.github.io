# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import pymongo
import json

# %%
file = "pedestrian_data.csv"

pedestrian_df = pd.read_csv(file, low_memory=False)
pedestrian_df.head()
# Out:
#                        Geo Point  \
# 0   35.9615971067, -78.977202721
# 1  35.9036670914, -79.0442027378
# 2  35.9081170935, -79.0239027322
# 3  35.9595671065, -78.9557027141
# 4  35.9470771036, -78.9785027202
#
#                                            Geo Shape  objectid_1  objectid  \
# 0  {u'type': u'Point', u'coordinates': [-78.97720...        4394    1847.0
# 1  {u'type': u'Point', u'coordinates': [-79.04420...        1962    1962.0
# 2  {u'type': u'Point', u'coordinates': [-79.02390...       10245     364.0
# 3  {u'type': u'Point', u'coordinates': [-78.95570...       10326     445.0
# 4  {u'type': u'Point', u'coordinates': [-78.97850...       10703     822.0
#
#   Ambulance         City  County crashalcoh Day of Week       Date  ...  \
# 0       Yes       Durham  Durham        Yes      Friday  14NOV2008  ...
# 1        No  Chapel Hill  Orange         No   Wednesday  31JAN2007  ...
# 2       Yes  Chapel Hill  Orange         No    Thursday  24FEB2011  ...
# ...

# %%
# Removing un-needed columns

dropped_df = pedestrian_df.drop(["Geo Point", "Geo Shape", "objectid_1", "objectid", "Ambulance", "City", "County", "crashalcoh","Day of Week", "Date", "Cause of Crash", "Hour of Crash", "Location of Crash", "Crash Month", "Crash Time", "Crash Type", "crash_ty_1", "Crash Year", "Development", "Driver Age", "Driver Injury", "Driver Race", "Driver Sex", "Vehicle Type", "excsspdind", "Hit and Run", "latitude", "Light Conditions", "Locality", "longitude", "Number of Lanes", "Number of Units", "Pedestrian Age Group", "Pedestrian Age", "Pedestrian Injury", "Pedestrian Position", 
                "Pedestrian Race", "Pedestrian Sex", "Road Characteristic", "Road Class", "Road Configuration", "Road Defects", "Road Feature", "Road Surface", "Region", "Rural/Urban", "Speed Limit", "Traffic Control", "Weather", "Workzone"], axis=1)
dropped_df.head()
# Out:
#            crsh_sevri drvrage_gr drvr_alc_d drvr_estep ped_alc_dr rd_conditi
# 0                 NaN      40-49         No    Unknown        Yes        Wet
# 1        O: No Injury      40-49         No    0-5 mph         No        Dry
# 2  C: Possible Injury      20-24         No    Unknown         No        Dry
# 3   B: Evident Injury      40-49         No  36-40 mph         No        Dry
# 4   B: Evident Injury      30-39         No    0-5 mph         No        Dry

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.crash_db
collection = db.pedestrian_information

# %%
records = json.loads(dropped_df.T.to_json()).values()

# %%
db.pedestrian_information.insert_many(records)
