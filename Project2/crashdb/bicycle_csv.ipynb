# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#This-notebook-transforms-the-biker-data-csv." data-toc-modified-id="This-notebook-transforms-the-biker-data-csv.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>This notebook transforms the biker data csv.</a></span></li></ul></div>

# %% [markdown]
# ### This notebook transforms the biker data csv.
#
# * Un-needed columns removed

# %%
import pandas as pd
import pymongo
import json

# %%
# Imported file into Pandas

file = "bicycle_data.csv"

df = pd.read_csv(file, low_memory=False)
df.head()
# Out:
#                        Geo Point  \
# 0   35.920493095, -79.0517427412
# 1  35.9116570929, -79.0626027443
# 2  35.9292600975, -79.0340327369
# 3  35.9109370928, -79.0673027457
# 4  35.9156790936, -79.0573827427
#
#                                            Geo Shape Ambulance  \
# 0  {u'type': u'Point', u'coordinates': [-79.05174...        No
# 1  {u'type': u'Point', u'coordinates': [-79.06260...       Yes
# 2  {u'type': u'Point', u'coordinates': [-79.03403...       Yes
# 3  {u'type': u'Point', u'coordinates': [-79.06730...       Yes
# 4  {u'type': u'Point', u'coordinates': [-79.05738...       Yes
#
#   Biker Age Group Biker Age  Bike Direction        Biker Injury  \
# 0           20-24        20    With Traffic      Unknown Injury
# 1           50-59        54    With Traffic  C: Possible Injury
# 2          10-Jun         8         Unknown   B: Evident Injury
# 3           50-59        51  Facing Traffic  C: Possible Injury
# ...

# %%
# Removing un-needed columns

dropped_df = df.drop(["Geo Point", "Geo Shape", "Ambulance", "Biker Age Group", "Biker Age", "Biker Injury", "Bike Direction", "Bike Position", "Biker Race", "Biker Sex", "City", "County", "Day", "Cause of Incident", "Location of Crash", "Month", "Time (Military Time)", "Crash Type", "Year", "Development", "Driver Age", "Driver Injury", "Driver Race", "Driver Sex", "Driver Vehicle Type", "Excessive Speeding", "Hit and Run", "Lighting Conditions", "Locality", "Number of Lanes", "Number of Units", "Road Characteristics", "Road Class", "Road Configuration", "Road Defects", "Road Feature", "Road Surface", "Rural/Urban", "Speed Limit", "Traffic Control", "Weather", "Workzone"], axis=1)
dropped_df.head()
# Out:
#   crashalcoh          crsh_sevri drvrage_gr drvr_alc_d drvr_estep rd_conditi
# 0         No        O: No Injury      20-24         No    Unknown        Dry
# 1         No  C: Possible Injury      30-39         No    0-5 mph        Wet
# 2         No   B: Evident Injury      30-39         No    0-5 mph        Dry
# 3         No  C: Possible Injury      40-49         No  11-15 mph        Dry
# 4         No   B: Evident Injury      20-24         No   6-10 mph        Dry

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.crash_db
collection = db.biker_information

# %%
records = json.loads(dropped_df.T.to_json()).values()

# %%
db.biker_information.insert_many(records)
